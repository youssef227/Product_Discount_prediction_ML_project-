# %%
# pip install requests

# %%
import requests
import csv

# %%
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36',
'authority':'www.carrefouregypt.com',
    'method':'GET',
    'path':'/api/v4/sponsored/products?keyword=&categoryId=FEGY1760000&filter=&areaCode=Maadi%20-%20Cairo&lang=ar&longitude=31.266225954206813&latitude=29.967909028696003',
    'scheme':'https',
    'accept':'*/*',
    'accept-encoding':'gzip, deflate, br',
    'accept-language':'en-US,en;q=0.9,ar;q=0.8',
    'appid':'Reactweb',
    'cookie':'cart_api=v2; flixgvid=flixdc40d2f3000000.57374999; inptime0_14582_a1=0; inptime0_14582_ar=0; cart_api=v2; app_version=v4; ROUTE=.accstorefront-759b54c6d4-nnr8s; ARRAffinity=73c10aeec864dcad6161b603e5d83fd79cc46905e75bcb7ae11b371bc3bf79e0; mafegy-web-preferred-delivery-area="Maadi - Cairo"; maf-cookie-banner-accepted=true; search_type=search_native; guest-session-token=6d_qonQVWbN6V6qo2GmRLdfXV78; maf-session-id=9e86a620-d5af-4af8-87da-20e38bfc25ad; mafegy-preferred-delivery-area=Maadi - Cairo; prevAreaCode=Maadi - Cairo; storeInfo=mafegy|ar|EGP; page_type=categorySearch; _abck=526A79C3CB19DB7FBE8DF7E36660E205~-1~...~-1~-1~-1; ak_bmsc=D2B9AED39366BE29CB7E270B924770CB~000000000000000000000000000000~...; bm_sz=5180674FB4604E2281E1B2463E40301A~~3748421~4272436; JSESSIONID=E780545D568DED6A7E1B56665E2E756C.accstorefront-759b54c6d4-nnr8s; bm_mi=B4C3B645811E1611887B53B1051B93EB~~1; bm_sv=FF4973421D90F0820D8B71C0C20DF46D~~1',
    'credentials':'include',
    'env':'prod',
#     'if-modified-since':'Sun, 23 Apr 2023 23:53:05 GMT',
#     'if-none-match':'W/"2-l9Fw4VUO7kr8CvBlt4zaMCqXZ0w"',
    'intent':'STANDARD',
    'lang':'ar',
#     'referer':'https://www.carrefouregypt.com/mafegy/ar/c/FEGY1760000?currentPage=1&filter=&pageSize=60&sortBy=relevance',
    'sec-ch-ua':'"Chromium";v="112", "Google Chrome";v="112", "Not:A-Brand";v="99"',
    'sec-ch-ua-mobile':'?0',
    'sec-ch-ua-platform':'"Windows"',
    'sec-fetch-dest':'empty',
    'sec-fetch-mode':'cors',
    'sec-fetch-site':'same-origin',
    'storeid':'mafegy',
    'token':'undefined',

}

# %%
# supermarket
url_1 = 'https://www.carrefouregypt.com/api/v8/categories/FEGY1700000?filter=&sortBy=relevance&pageSize=60&maxPrice=&minPrice=&areaCode=Maadi%20-%20Cairo&lang=ar&displayCurr=EGP&latitude=29.967909028696003&longitude=31.266225954206813&nextOffset=&requireSponsProducts=true&responseWithCatTree=true&depth=3&currentPage={}'
# drinks
url_2 = 'https://www.carrefouregypt.com/api/v8/categories/FEGY1500000?filter=&sortBy=relevance&pageSize=60&maxPrice=&minPrice=&areaCode=Maadi%20-%20Cairo&lang=ar&displayCurr=EGP&latitude=29.967909028696003&longitude=31.266225954206813&nextOffset=&requireSponsProducts=true&responseWithCatTree=true&depth=3&currentPage={}'
# Dairy products and eggs
url_3 = 'https://www.carrefouregypt.com/api/v8/categories/FEGY1630000?filter=&sortBy=relevance&pageSize=60&maxPrice=&minPrice=&areaCode=Maadi%20-%20Cairo&lang=ar&displayCurr=EGP&latitude=29.967909028696003&longitude=31.266225954206813&nextOffset=&requireSponsProducts=true&responseWithCatTree=true&depth=3&currentPage={}'

# %%
pg_num = 0
val = 0
names = []

# %%
while True:
    response = requests.get(url_3.format(pg_num), headers=headers)
    data = response.json()
    products = data["products"]
    if True:
        print("Dictionary is not empty!")
        pg_num += 1
        for i in products:
            for key,value in i.items():
                if key == 'name':
                    names[val].append(value.strip())
                    val+=1
                if key == 'ean':
                    names.append([value.strip()])
        print(val)
        names
    if pg_num >= 50:
        break
#     else:
#         print("Dictionary is empty!")
#         break
# Out:
# Dictionary is not empty!
# 60
# Dictionary is not empty!
# 119
# Dictionary is not empty!
# 178
# Dictionary is not empty!
# 233
# Dictionary is not empty!
# 290
# Dictionary is not empty!
# 347
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375
# Dictionary is not empty!
# 375

# %%
print(val)
names
# Out:
# 375
# [['6223000350003', 'حليب كامل الدسم جهينة - 1.5 لتر'],
#  ['6224001105005', 'لمار حليب كامل الدسم - 1 لتر'],
#  ['2122157000004', 'جبنة رومي بطارخ'],
#  ['6223001878018', 'لبن المراعي كامل الدسم، 1.5 لتر'],
#  ['6222014314063', 'لبن كامل الدسم من جهينه - 1 لتر - 6 عبوات'],
#  ['6223000350256', 'لبن بخيره كامل الدسم جهينة - 1 لتر'],
#  ['6224001105012', 'حليب لمار خالي الدسم - 1 لتر'],
#  ['6224001105029', 'لبن لمار نصف دسم - 1 لتر'],
#  ['6222014354342', 'زبادي طبيعي من جهينه - 105 جرام - 9+3 عبوة'],
#  ['2122015000009', 'دومتي جبنة ثلاجة ملح خفيف'],
#  ['6223001878001', 'لبن كامل الدسم المراعي - 1 لتر'],
#  ['6223000350065', 'لبن جهينة كامل الدسم - 1 لتر'],
#  ['2122158000003', 'جبن رومي بطارخ بالفلفل'],
#  ['2122393000004', 'جبنة موتزاريلا مبشورة'],
#  ['6223001876854', 'حليب بالشوكولاتة المراعي تريتس، 200 مل'],
#  ['6223001875413', 'زبادي طبيعي من المراعي - 105 جم - 9+3 عبوة'],
#  ['6223001878308', 'لبن خالي الدسم المراعي - 1 لتر'],
#  ['6223001876861', 'حليب بالفراولة المراعي تريتس، 200 مل'],
#  ['6223003771232', 'جبنة فيتا بريزيدن - 500 جم'],
#  ['6223000350027', 'حليب خالي الدسم جهينة - 1.5 لتر'],
#  ['6223001351146', 'زبدة خليط فيرن - 1 كجم'],
#  ['3073781014044', 'جبنة كيري مربعات - 12 قطعة'],
#  ['2122010000004', 'جبنة قريش'],
#  ['3228021060460', 'جبنة مثلثات بريزيدن - 32 قطعة'],
#  ['2122153000008', 'جبن رومي ايكسترا'],
#  ['6222014310881', 'لبن جهينة ميكس بالشيكولاتة - 200 مل'],
#  ['2122680000007', 'جبنة شيدر من ماينز/ كيلو جرام'],
#  ['6223001878025', 'لبن المراعي خالي الدسم، 1.5 لتر'],
#  ['6223001876908', 'حليب بالموز المراعي تريتس، 200 مل'],
#  ['2122071000005', 'جبنة براميلي'],
#  ['6223000350010', 'حليب جهينة كامل الدسم - 200 مل'],
#  ['6223003699109', 'زبدة انكور غير مملحة - 200 جم'],
#  ['6281007033152', 'زبدة طبيعية غير مملحة من المراعي - 400 جرام'],
#  ['3228021060040', 'جبنه بريزيدن سبريد مطبوخه بالقشطة - 240 جرام'],
#  ['3228022070093', 'جبنة فيتا قشطة بريزيدن - 500 جم'],
#  ['6223003776800', 'لبن لاكتيل كامل الدسم - 1 لتر'],
#  ['6281007033176', 'المراعي زبدة طبيعية غير مملحة - 200 جم'],
#  ['6222014314087', 'لبن خالي الدسم من جهينه - 1 لتر - 6 عبوات'],
#  ['6223001874294', 'لبن المراعي كامل الدسم - 1 لتر'],
#  ['3228023000037', 'جبنة بريزيدن مثلثات - 16 قطعة'],
#  ['2122072000004', 'جبنة براميلي بالفلفل'],
#  ['6223002381029', 'بودينج دانيت بالشوكولاتة، 100 جم - 7+1 عبوة'],
#  ['6223000350072', 'لبن جهينة نصف دسم - 1 لتر'],
#  ['6222014310898', 'لبن جهينة ميكس بالفراولة - 200 مل'],
#  ['2122319000002', 'جبنة تشيدر ايرلندي'],
#  ['6223001876366', 'حليب المراعي كامل الدسم - 200 مل'],
#  ['6223000750070', 'جبنة موزاريلا مبشورة دومتي - 280 جم'],
#  ['2122168000000', 'جبنة رومي شمع'],
#  ['6223007520812', 'المراعي لبن نصف دسم - 1 لتر'],
#  ['6222014318016', 'كريمة طبخ جهينة - 1 لتر'],
#  ['6224001105036', 'حليب لمار كامل الدسم - 200 مل'],
#  ['6223006510883', 'لاكتيل زبادي سادة - 6+2'],
#  ['6223003771256', 'بريزيدون جبن أبيض لايت - 500 جرام'],
#  ['6224008709008', 'لبن عبور لاند كامل الدسم - 1 لتر'],
#  ['6223000350089', 'لبن جهينة خالي الدسم - 1 لتر'],
#  ['2122684000003', 'جبنة مدخنة من ماينز'],
#  ['6223000352625', 'جهينة زبادو مشروب زبادي بالفراولة - 440 مل'],
#  ['6223000350157', 'حليب بخيره كامل الدسم - 500 مل'],
#  ['6223000350461', 'لبن جهينة ميكس بالفانيليا - 200 مل'],
#  ['6223000757123', 'جبنة فيتا دومتي بلس - 1 كجم'],
#  ['6223000352656', 'مشروب زبادي زبادو بالخوخ - 440مل'],
#  ['6223000350454', 'لبن جهينة ميكس بالكراميل - 200 مل'],
#  ['6223000758717', 'دومتى لبن كامل الدسم - 1 لتر'],
#  ['3073781086478', 'كيري لبنة كريمي - 350 جم'],
#  ['2122026000005', 'جبنة دومتي براميلي'],
#  ['6222014351877', 'زبادي جهينة لايت - 105جم - عبوة من 9+3'],
#  ['6223001874317', 'لبن نصف دسم المراعي - 1 لتر'],
#  ['6224011439015', 'مزارع دينا جبن أبيض طري - 500 جرام'],
#  ['6222014317019', 'كريمه خفق من جهينه - 1 لتر'],
#  ['3073781100112', 'جبنة مثلثات ابو الولد - 32 قطعة'],
#  ['6223003771522', 'مشروب زبادي لاكتيل دويتو بالفراولة - 420مل'],
#  ['2122024000007', 'جبنة ملح خفيف'],
#  ['2122188000004', 'جبنة ملح خفيف قتيلو'],
#  ['3073781067842', 'جبنة مثلثات ابو الولد - 16 قطعة'],
#  ['6223002384525', 'أويكو زبادي يوناني سادة - 170 جرام'],
#  ['6223000756461', 'جبنة فيتا دومتي، ملح خفيف - 1 كجم'],
#  ['6223001873563', 'كريمة طهي المراعي - 1 لتر'],
#  ['6223000352649', 'جهينة زبادو مشروب زبادي بالمانجو - 440 مل'],
#  ['2122461000004', 'موبي جبن ريكفورد'],
#  ['6222014310805', 'حليب جهينة 0% دسم - 1 لتر'],
#  ['3228022070062', 'جبنة اسطنبولي بريزيدن - 450 جم'],
#  ['6223003773755', 'جبنة اسطنبولي من بريزيدن - 700 جرام'],
#  ['6281007037181', 'المراعي لبنة فاخرة كاملة الدسم - 180 جرام'],
#  ['6223004830020', 'جبنة ملح خفيف من قتيلو - 454 جرام'],
#  ['6224011439022', 'مزارع دينا جبنة ملح خفيف - 500 جرام'],
#  ['3073781136388', 'جبنة مثلثات لافاش كيري - 24 قطعة'],
#  ['6223001873587', 'كريمة خفق المراعي - 1 لتر'],
#  ['6223002384549', 'زبادي اويكو يوناني بالتوت - 140 جرام'],
#  ['6223003773748', 'جبنة براميلي من بريزيدن - 700 جرام'],
#  ['3228023060260', 'جبنه بريزيدن سبريد مطبوخه بالجبنة الرومي - 240 جرام'],
#  ['6224007244029', 'جبنه بريزيدن سبريد مطبوخه لايت - 240 جرام'],
#  ['6223002384594', 'اويكو زبادي يوناني لايت - 170 جرام'],
#  ['6223001875482', 'المراعي زبادي طبيعي - 105 جرام - 6 علب'],
#  ['6223001870081', 'زبادي يوناني المراعي سادة - 2% دهون - 170 جرام'],
#  ['2122017000007', 'جبنة اسطنبولي دومتي'],
#  ['3073781180152', 'جبنة مثلثات لا فاش كي ري - 16 قطعة'],
#  ['6224007244937', 'جبنه بريزيدن سبريد مطبوخه بالجبنة المدخنة - 240 جرام'],
#  ['6223002380671', 'حليب بالفراولة دانون دانجو - 200 مل'],
#  ['3073781159875', 'جبنة مثلثات لافاش كيري - 32 قطعة'],
#  ['3073781101546', 'جبنة مثلثات لافاش كيري - 24 قطعة'],
#  ['3073781153392', 'جبنة مثلثات أبو الولد - 8 قطع - 5 علب'],
#  ['2122007000000', 'جبن بريزيدون ملح خفيف'],
#  ['6223002383375', 'مشروب دانون هاي برو بالفراولة - 260 جم'],
#  ['6223001876038', 'حليب المراعي كامل الدسم، 1 لتر - 6 عبوات'],
#  ['6223004834219', 'كاتيلو سمن طبيعي - 900 جرام'],
#  ['6223000757291', 'جبنة اسطنبولي بلس دومتي - 500 جم'],
#  ['6223001874300', 'لبن المراعي خالي الدسم - 1 لتر'],
#  ['6223004834011', 'جبنة دمياطي قتيلو - 2 كجم'],
#  ['6222014353109', 'جهينة زبادي بوناني بالفراولة - 180 جرام'],
#  ['6224008637066', 'حليب لمار بالفراولة - 200 مل'],
#  ['6224011439046', 'مزارع دينا جبنة إسطنبولي - 500 جرام'],
#  ['3073781019490', 'لبنة كريمية كيري - 500 جم'],
#  ['6223001877943', 'كريمة الخفق من المراعي - 500 مل'],
#  ['3228022060179', 'جبنة شيدر سبريد بريزيدون - 500 جم'],
#  ['6224008637059', 'حليب لمار بالشوكولاتة - 200 مل'],
#  ['3073781086461', 'جبنة كريمي سبريد كيري - 500 جم'],
#  ['6223004261626', 'جبنة مربعات كيري بالقشطة - 48 قطعة'],
#  ['2122544000006', 'جبنة كيرى بطعم البسطرمة'],
#  ['6224000054847', 'حليب كامل الدسم بشاير - 1 لتر'],
#  ['3073781086454', 'جبنة كيري كريمي سبريد - 350 جم'],
#  ['6222014353116', 'جهينة زبادي بوناني بالتوت - 180 جرام'],
#  ['3073781028348', 'جبنة كيري مربعات - 8 قطع'],
#  ['6223004830419', 'جبنة براميلي قتيلو - 1.5كجم'],
#  ['6223003771652', 'جبن سبريد مدخن بالقشطة بريزيدون - 500 جم'],
#  ['6223002389384', 'اويكو زبادي يوناني بتشيز كيك الفراولة - 170 جرام'],
#  ['6222014353130', 'جهينة زبادي بوناني بالخوخ - 180 جرام'],
#  ['2122481000008', 'جبنة إيدام تشيزا'],
#  ['6224008637196', 'كريمة طهي لمار - 1 لتر'],
#  ['6224001105302', 'حليب لمار خالي الدسم - 200 مل'],
#  ['6222014352195', 'زبادي يوناني جهينه 2% دسم - 180 جرام'],
#  ['6222014352201', 'زبادي يوناني جهينة، 5% دسم - 180 جم'],
#  ['6223002380664', 'حليب بالشوكولاتة دانون دانجو - 200 مل'],
#  ['6223001875017', 'المراعى تريتس زبادى بالخوخ - 100 جم'],
#  ['6224000147006', 'جبنة فيتا عبور لاند - 500جم'],
#  ['6223004260452', 'جبنة كيري مثلثات - 16 قطعة'],
#  ['6223004830211', 'جبنة إسطنبولي من قتيلو - 1500 جرام'],
#  ['6222014353147', 'جهينة زبادي بوناني بالفانيليا - 180 جرام'],
#  ['2122380000000', 'جبنة شيدر نيوزلندي'],
#  ['6222014352218', 'لبن رايب جهينة - 440مل'],
#  ['2122089000004', 'جبنة براميلي طازة'],
#  ['3228023060383',
#   'جبنة بريزيدن مطبوخ كامل الدسم قابل للفرد بالقشطة - 900 جم'],
#  ['6223001877950', 'كريمة خفق المراعي - 200مل'],
#  ['3073781052619', 'جبنة كيري كريمي سبريد - 200 جم'],
#  ['3228022070086', 'جبنة ثاتجة بريزيدن - 500 جم'],
#  ['3073781101539', 'جبنة مثلثات لافاش كيري مطبوخ - 16 قطعة'],
#  ['6223001878643', 'مشروب زبادي المراعي يو جو بالفراولة - 440 مل'],
#  ['6223002384051', 'كريم كراميل دانيت - 75 جم'],
#  ['2122068000001', 'لبنة (زبادي لبناني)'],
#  ['3073781155839', 'جبنة مثلثات لافاش كيري مطبوخ - 8 قطع - 5 علب'],
#  ['6223000752890', 'جبنة براميلي دومتي - 500جم'],
#  ['6223004771552', 'جبنة فيتا جرين لاند بالبسطرمة - 500 جم'],
#  ['6223003776121', 'جبنة مثلثات طعمة ميلك - 40 قطعة'],
#  ['6222014352287', 'زبادي يوناني جهينة، 7% دسم - 180 جم'],
#  ['6281007026017', 'المراعي بريميوم لبنة كاملة الدسم - 400 جرام'],
#  ['3073781136265', 'جبنة مثلثات لافاش كيرى - 40 قطعة'],
#  ['6223003770792', 'جبنة طعمة مثلثات - 32 قطعة'],
#  ['3228023000044', 'جبنة مثلثات بريزيدون - 24 قطعة'],
#  ['6223004830143', 'جبنة فيتا لايت قتيلو - 500 جم'],
#  ['2122016000008', 'جبنة فيتا من دومتي'],
#  ['3073781115031', 'كيري لبنة - 150 جرام'],
#  ['6223001874973', 'المراعى تريتس زبادى بفراوله - 100 جم'],
#  ['3073781115017', 'جبنة كيري كريمي سبريد - 150 جم'],
#  ['6221011000351', 'جبنة إسطنبولي دريم لاند - 500جم'],
#  ['2122191000008', 'قشطة طازجة قتيلو'],
#  ['6223001874928', 'المراعي زبادي طبيعي - 170 جرام'],
#  ['6223000757284', 'جبنة فيتا بلس بالزيتون دومتي - 500 جم'],
#  ['2122090000000', 'جبنة فيتا'],
#  ['3073781097580', 'جبنة مثلثات لافاش كيري مطبوخ - 8 قطع'],
#  ['2122679000001', 'جبنة مينز بالهالبينو'],
#  ['3073781139013', 'ظ„ظپط§ط´ ظƒظٹط±ظ‰ ط¬ط¨ظ†ط© ط¯ظٹط¨ط±ط²120ط¬'],
#  ['6223003776275', 'جبنة مثلثات بريزيدن - 80+8 قطعة'],
#  ['6223002383382', 'مشروب دانون هاي برو بالفانيليا - 260 جم'],
#  ['6224000036539', 'جبنة مثلثات طعمة ميلك - 24 قطعة'],
#  ['6223003771546', 'مشروب زبادي لاكتيل دويتو بالخوخ - 420مل'],
#  ['2122363000003', 'جبنة من جودة'],
#  ['3073781136302', 'جبنة لافاش كيري مثلثات - 64 قطعة'],
#  ['3073781153781', 'كيرى جبنة بالوصفة اليونانى - 350 جرام'],
#  ['6223000756645', 'جبنة فيتا بلس دومتي - 250 جم'],
#  ['6223003698355', 'زبدة أنكور نيوزيلندية نقية غير مملحة - 10 جرام - 10 قطع'],
#  ['3073781178555', 'جبنة مثلثات لافاش كيري بالقشطة - 8 قطع'],
#  ['3073781180176', 'جبنة مثلثات لافاش كيري - 48 قطعة'],
#  ['3073781162141', 'كيري جبنة تغميس - 35 جرام'],
#  ['6224000036034', 'جبنة مثلثات طعمة ميلك - 16 قطعة'],
#  ['2122057000005', 'لبنة من هاجدو'],
#  ['2122189000003', 'جبنة براميلي قتيلو'],
#  ['3073781028331', 'جبنة كيري مربعات - 6 قطع'],
#  ['6223000350386', 'جهينة كريمة مخفوقة - 200 مل'],
#  ['6223000755167', 'جبنة فيتا دومتي - 250 جم'],
#  ['6224000432195', 'مزارع دينا لبن شوكولاتة - 250 مللي'],
#  ['6223004833045', 'جبنة رومي قديمة قاتيلو - 200 جم'],
#  ['6223002380688', 'حليب بالموز دانون دانجو - 200 مل'],
#  ['6224000147143', 'جبنة فيتا عبور لاند - 250جم'],
#  ['2122018000006', 'دومتي جبنة دوبل كريم'],
#  ['6224011439039', 'مزارع دينا جبنة براميلي - 500 جرام'],
#  ['6223001874980', 'المراعي زبادي تريتس تارت فراولة - 100 جم'],
#  ['6223002383252', 'زبادي سادة طبيعي دانون، 105 جم - 6+2 عبوة'],
#  ['3073781101553', 'جبنة مثلثات لافاش كيري - 32 قطعة'],
#  ['6223000757550', 'دومتي جبنة فيتا بلس زيتون - 1 كجم'],
#  ['6223003777609', 'لبن لاكتيل كامل الدسم - 1 لتر - عبوة من 6'],
#  ['2122067000002', 'جبنة حلوم'],
#  ['6223001870098', 'زبادي يوناني المراعي بالفراولة - 170 جرام'],
#  ['6223001871019', 'زبادي يوناني المراعي سادة - 5% دهون - 170 جرام'],
#  ['6223004833038', 'قتيلو شرائح جبنة رومي قديمة - 454 جرام'],
#  ['6223002380343', 'بودينج فانيليا دانيت - 100جم'],
#  ['6223001875000', 'زبادي المراعي تريتس بالتوت - 100 جم'],
#  ['2122681000006', 'ماينز جبنة شيدر مطبوخ بالكمون'],
#  ['3228024060320', 'جبن سبريد بالقشطة بريزيدون - 500 جم'],
#  ['6223002380145', 'بودينج كاراميل دانيت - 100جم'],
#  ['6223004260445', 'جبنة كيري مثلثات - 8 قطع'],
#  ['6223001878520', 'المراعي لبن رايب - 220 مللي'],
#  ['2122718000009', 'بيرلا جبنة براميلي طازة'],
#  ['6223003776206', 'جبنة بيضاء بريزيدن لايت - 500جم'],
#  ['2122328000000', 'شيدر أحمر'],
#  ['3228023060376', 'جبنة شيدر بريزيدن مطبوخ كامل الدسم قابل للفرد - 900 جم'],
#  ['6223003777906', 'زبادي طبيعي من لاكتيل - 105 جم - 12 عبوة'],
#  ['6222014352416', 'جهينة لبن رايب - 220 مللي'],
#  ['3073780968508', 'جبنة بيبي بيل لا فاش كيري - 100 جم'],
#  ['3228022070055', 'جبنة رومي سبريد بريزيدون - 500 جم'],
#  ['6223001878810', 'المراعي يو جو مشروب زبادي فراولة - 220 مل'],
#  ['3228023950172', 'جبنة مثلثات بريزيدن مطبوخ كامل الدسم بالقشطة - 8 قطع'],
#  ['6223004833106', 'قتيلو جبن رومي قديم كامل الدسم - 600 جرام'],
#  ['6222014351396', 'جهينة زبادو مشروب زبادي بالتوت - 440 مل'],
#  ['3228022070079', 'جبنة براميلي بريزيدن - 500 جم'],
#  ['6224008637073', 'حليب لمار بالموز - 200 مل'],
#  ['6223003779146', 'لاكتيل زبادى طبيعى يونانى - 170 جرام'],
#  ['6223001875024', 'زبادي المراعي تريتس بالمانجو ، 100 جم'],
#  ['6223001878513', 'المراعي رايب - 440 مللي'],
#  ['3073781079234', 'جبنة مثلثات ابو الولد - 24 قطعة'],
#  ['3073781052633', 'كيرى لبنه كريمي - 200 جرام'],
#  ['2122683000004', 'جبنة مينز بالشيدر الحمراء'],
#  ['2122084000009', 'جبنة اسطمبولي'],
#  ['6224008637240', 'لمار كريمة مخفوقة - 200 مل'],
#  ['2122402000001', 'شيدر مصري'],
#  ['2122686000001', 'زبدة خليط 30%'],
#  ['6222014310928', 'لبن جهينة ميكس بالموز - 200 مل'],
#  ['6223000752975', 'جبنة فيتا بالزيتون دومتي - 500جم'],
#  ['2122748000000', 'جبنة موزاريلا مبشورة'],
#  ['2122020000001', 'جبنة اسطمبولي طازة'],
#  ['6223007520386', 'المراعي زبادى يوناني بالتوت - 170 جرام'],
#  ['6223003778163',
#   'زبادي لاكتيل كلاوني - 105 جم - 6 عبوات - + زبادي لاكتيل طبيعي - 105 جم - 6 عبوات'],
#  ['6222014354472', 'زبادي طبيعي جهينة - 105جم - 6+2 عبوة'],
#  ['2122885000000', 'خليط زبدة نيوزيلاندا'],
#  ['6223000758915', 'دومتي فيتا بلس جبنة شيدر - 250 جرام'],
#  ['6224000490072', 'جبنة شيدر ضيافة - 400 جم'],
#  ['2122384000006', 'جبنة بطعم إيدام تشيزا'],
#  ['6224008267812', 'جبنة فيتا تشيزا - 450 جرام'],
#  ['6224000036027', 'جبنة مثلثات طعمة ميلك - 8 قطع'],
#  ['6223000758939', 'دومتي بلس جبنة فيتا بالرومي - 250 جرام'],
#  ['6222014300035', 'جهينة زبادي لايت - 180 جرام'],
#  ['6223000750742', 'دومتي جبن أبيض طري عالي الدسم نباتي الدهن - 800 جرام'],
#  ['6223000351376', 'جهينة زبادي طبيعي - 105 جرام - 12 علبة'],
#  ['6223002380497', 'دانون زبادي طبيعي - 103 جرام - 9 زائد 3 علب مجانًا'],
#  ['2122390000007', 'جبنة شيدر أحمر'],
#  ['2122197000002', 'زبدة  إيرلندية/كيلو جرام'],
#  ['2122732000009', 'جبنة قريش بيرلا'],
#  ['6224008267836', 'جبنة براميلي تشيزا - 450جم'],
#  ['2122906000002', 'جبنة رومي اكسترا'],
#  ['6222014318023', 'جهينة كريمة طهي - 500 مل'],
#  ['2122687000000', 'زبدة خليط 10%'],
#  ['6224008470168', 'هيلثي زبادي طبيعي - 105 جرام'],
#  ['6224008267829', 'جبنة إسطنبولي تشيزا - 450 جرام'],
#  ['6222014317026', 'جهينة كريمة مخفوقة - 500 مل'],
#  ['2122064000005', 'جبنة عكاوي'],
#  ['6225000339590', 'إيطاليانو جبنة فور تشيز - 900 جرام'],
#  ['6224008709015', 'لبن عبور لاند 0 دهون - 1 لتر'],
#  ['3073781058185', 'جبنة مثلثات ابو الولد - 8 قطع'],
#  ['2122720000004', 'بيرلا جبنة كريمي دابل'],
#  ['6224010623125', 'يوبوليس زبادي يوناني بالميكس توت - 150 جرام'],
#  ['2122027000004', 'سلطه جبنه قريش'],
#  ['6224001105289', 'لمار حليب كامل الدسم 500م'],
#  ['6281007033190', 'المراعي زبدة طبيعية غير مملحة - 100 جرام'],
#  ['2122905000003', 'جنة رومي بطارخ فاكيوم'],
#  ['2122062000007', 'جبنة مشللة'],
#  ['6224011439121', 'زبدة مزارع دينا نقية غير مملحة - 900 جرام'],
#  ['6224008637486',
#   'ظ„ظ…ط§ط± ط\xadظ„ظٹط¨ ط¨ط§ظ„ظƒظˆظƒظٹط² ظˆ ط§ظ„ظƒط±ظٹظ…ظ‡ 200 ظ…'],
#  ['6224010623026', 'يوبوليس جريك زبادى يونانى طبيعى - 2% دسم - 150 جرام'],
#  ['2122727000007', 'جبنة قطع بسطرمة بيرلا'],
#  ['3073781104325', 'جبنة لافاش شرائح شيدر - 180 جرام'],
#  ['6224000432157', 'مزارع دينا لبن فراولة - 250 مللي'],
#  ['6224000036256', 'جبنة فيتا طعمة ميلك - 250 جم'],
#  ['6223003193041', 'كب كيك راز بالفراولة - 1 قطعة'],
#  ['6224010623057', 'يوبوليس زبادي يوناني بتارت الليمون - 150 جرام'],
#  ['2122031000007', 'جبنة كيرى بالزيتون'],
#  ['6224000147013', 'جبنة إسطنبولي عبور لاند - 500جم'],
#  ['6223003193010', 'راز كب كيك بالفانيليا - 1 قطعة'],
#  ['6224000036249', 'جبنة فيتا من طعمة - 500 جرام'],
#  ['6224008709930', 'حليب عبور لاند كامل الدسم - 500 مل'],
#  ['2122039000009', 'جبن مش بالبابريكا'],
#  ['3228021070025', 'جبنة مثلثات بريزيدن مطبوخ كامل الدسم بالقشطة - 48 قطعة'],
#  ['3228021020235', 'جبنة مربعات بريزيدن مطبوخ بالقشطة - 6 قطع'],
#  ['2122386000004', 'جبنة بطعم الفلفل تشيزا'],
#  ['6224000036744', 'جبنة اسطنبولي من طعمة - 500 جرام'],
#  ['6222014300448', 'جهينة زبادى طبيعى - 115 جرام'],
#  ['6223002384532', 'زبادي اويكو يوناني بالكراميل المملح - 170 جرام'],
#  ['6221007000709', 'مشروب زبادى نستلة جو بالفراولة - 380 مل'],
#  ['6224000147594', 'جبنة فيتا عبورلاند - 125 جم'],
#  ['6224008637202', 'كريمة خفق لمار - 1 لتر'],
#  ['6223006520547', 'عبور لاند جبنة شيدر - 250 جرام'],
#  ['3228021060019', 'جبنة شيدر بريزيدن مطبوخ كامل الدسم قابل للفرد - 140 جم'],
#  ['6222014354526', 'زبادي جهينه بالفراولة - 105 جرام - 5+1 عبوة'],
#  ['2122733000008', 'جبنة قريش بالفلفل بيرلا'],
#  ['3228023010081', 'جبنة مربعات بريزيدن مطبوخ بالقشطة - 8 قطع'],
#  ['6223002384204', 'مشروب زبادي دانون ماكس بالخوخ - 220جم'],
#  ['6223000753279', 'دومتي كريمي بالجبنة الرومي - 220 جرام'],
#  ['6223000753811', 'دومتي فيتا بلس جبنة بطعم البسطرمة - 220 جرام'],
#  ['3073781153767', 'كيرى جبنة بالوصفة اليونانى - 200 جرام'],
#  ['6223006520783', 'عبور لاند جبنة بطعم الجبنة القديمة - 500 جم'],
#  ['3228021060033',
#   'جبنة بريزيدن مطبوخ كامل الدسم قابل للفرد بالقشطة - 140 جم'],
#  ['6224000036676', 'جبنة اسطنبولي طعمة ميلك - 250 جم'],
#  ['3073781078978', 'جبنة لافاش كيري بالقشطة - 200 جم'],
#  ['3228023060253', 'بريزيدن جبنة سبريد بطعم جبنة الرومي - 140 جرام'],
#  ['6223007521048', 'المراعي تريتس حليب بالفراولة - 235 مل'],
#  ['3073781097870', 'جبنة شيدر لافاش كيري - 200 جم'],
#  ['6223007521031', 'المراعي تريتس حليب بالشوكولاتة - 200 مل - 6 عبوات'],
#  ['2122513000006', 'جبنة ريكفورد'],
#  ['2122042000003', 'لحم بارد'],
#  ['6224007244920', 'جبنة مدخنة بريزيدن كامل الدسم قابل للفرد - 140 جم'],
#  ['6223003778972', 'لاكتيل زبادي طبيعي - 170 جرام'],
#  ['6224008637431', 'لمار حليب اللوز - 1 لتر'],
#  ['6222014300172', 'جهينه إن اند جي حليب لوز - 1 لتر'],
#  ['3073781097832', 'جبنة قشطة قابلة للفرد لافاش كيري - 350 جم'],
#  ['2122741000007', 'ميش بيرلا اكسترا'],
#  ['6223007791199', 'روتانا زبدة طبيعية غير مملحة - 100 جرام'],
#  ['6224000147532', 'عبور لاند جبنة فيتا - 1 كجم'],
#  ['2122907000001', 'جبنة رومي اسبشيال'],
#  ['2122892000000', 'برطمان جبنة سبريد بيرلا'],
#  ['6223003193034', 'كب كيك راز بكريمة شوكولاتة البيضاء، 1 قطعة - 12 عبوة'],
#  ['6223003695095', 'روتانا زبدة طبيعية - 400 جرام'],
#  ['6224007244470', 'جبنة فيتا طعمة ميلك رويال - 1 كجم'],
#  ['6223003695071', 'روتانا زبدة طبيعية - 200 جرام'],
#  ['2122891000001', 'برطمان جبنة سبريد بالزيتون بيرلا'],
#  ['2122717000000', 'بيرلا جبنة فيتا'],
#  ['6221007091066', 'زبادي نستله بالفراولة - 105جم'],
#  ['3073781187649',
#   'كيري مربعات الجبن اليوناني قابلة للدهن - 24 قطعة - 400 جرام'],
#  ['6223004830433', 'جبنة براميلي قتيلو - 250جم'],
#  ['2122195000004', 'مش دمياطي قتيلو'],
#  ['6223003776817', 'حليب لاكتيل خالي الدسم - 1 لتر'],
#  ['2122619000009', 'جبنة امنتال'],
#  ['2122190000009', 'جبنة اسطمبولي'],
#  ['6223004834318', 'كاتليو مورتا - 250 جرام'],
#  ['2122719000008', 'جبنة اسطنبولي بيرلا'],
#  ['2122040000005', 'لحم بارد بالمايونيز'],
#  ['6224008470298', 'هيلثي لبن رايب - 270 مل'],
#  ['6223004830235', 'جبنة اسطنبولي قتيلو - 250 جم'],
#  ['6223004830136', 'جبنة فيتا لايت قتيلو - 250 جم'],
#  ['2122778000001', 'جبنة ريكفورد'],
#  ['6223007521055', 'المراعي تريتس حليب بالموز - 235 مل'],
#  ['2122682000005', 'جبنة بالزيتون الأخضر من ماينز/كيلو جرام'],
#  ['6223000753149', 'كريمة شوكولاتة دومتي بالبندق - 240 جم'],
#  ['6224008470304', 'هيلثي لبن رايب بالفراولة - 270 مل'],
#  ['2122192000007', 'جبنة كريمي قتيلو'],
#  ['6221011003048', 'جبنة اسطنبولي جرين لاند - 1 كجم'],
#  ['6224007244463', 'جبنة اسطنبولي طعمة ميلك رويال - 1 كجم'],
#  ['6223003774608', 'جبنة دمياطي طعمة ميلك - 1 كجم'],
#  ['6221011000412', 'جبنة فيتا جرين لاند - 1 كجم'],
#  ['2122223000006', 'جبنة جرانا بدانو'],
#  ['2122920000002', 'جبنة فيتا سادة شطورة - كيلو'],
#  ['6223004834028', 'جبنة دمياطي فتيلو طبيعية - 1كجم'],
#  ['6223003770006', 'جبنة بريزيدن مطبوخ كامل الدسم بالبلوتشيز - 14 جم'],
#  ['6223003776244', 'جبنة فيتا طعمة لايت - 500جم'],
#  ['2122019000005', 'جبنة فيتا'],
#  ['5411188125341', 'البرو حليب بخلاصة اللوز - 1 لتر'],
#  ['6223001877172', 'لبن بالموز المراعي - 200 مل'],
#  ['6223004773488', 'جرين لاند فيتا الصفرا بالخلطة الأصلية - 500 جرام'],
#  ['2122329000009', 'جبنة امنتال سويسري'],
#  ['2122131000006', 'جبنة شيدر بيضاء بالفلفل الحار'],
#  ['2122240000003', 'جبنة ايمينتال سويسري'],
#  ['2122340000002', 'جبن جرويير'],
#  ['2122728000006', 'بيرلا صوص جبنة زرقاء'],
#  ['8690565130704', 'لبنة بينار - 180جم'],
#  ['2122159000002', 'جبنة ريكفورد كليمنس'],
#  ['2122356000003', 'جبنة كشكفال بقرى مدخن'],
#  ['2122398000009', 'جبنة شيدر بيضاء قليلة الدسم'],
#  ['8690565040720', 'لبنة بينار - 370جم'],
#  ['8690565016435', 'لبنة بينار - 700 جرام + لبنة بينار - 180 جرام']]

# %%
fields = ['product_name', 'Product_id']
with open('all products.csv', 'a',encoding="utf-8-sig") as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
    # write.writerow(fields)
    write.writerows(names)
